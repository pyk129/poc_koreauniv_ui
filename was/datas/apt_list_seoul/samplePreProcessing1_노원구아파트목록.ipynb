}
listBjdCodes.append(bjdCode)
bjdCode = {'name':'영등포구','bjdcode':['1156010100',
'1156010200',
'1156010300',
'1156010400',
'1156010500',
'1156010600',
'1156010700',
'1156010800',
'1156010900',
'1156011000',
'1156011100',
'1156011200',
'1156011300',
'1156011400',
'1156011500',
'1156011600',
'1156011700',
'1156011800',
'1156011900',
'1156012000',
'1156012100',
'1156012200',
'1156012300',
'1156012400',
'1156012500',
'1156012600',
'1156012700',
'1156012800',
'1156012900',
'1156013000',
'1156013100',
'1156013200',
'1156013300',
'1156013400']}
listBjdCodes.append(bjdCode)

bjdCode = {'name':'동작구','bjdcode':['1159010100',
'1159010200',
'1159010300',
'1159010400',
'1159010500',
'1159010600',
'1159010700',
'1159010800',
'1159010900']}
listBjdCodes.append(bjdCode)
bjdCode = {'name':'관악구','bjdcode':['1162010100',
'1162010200',
'1162010300']}
listBjdCodes.append(bjdCode)
bjdCode = {'name':'서초구','bjdcode':['1165010100',
'1165010200',
'1165010300',
'1165010400',
'1165010600',
'1165010700',
'1165010800',
'1165010900',
'1165011000',
'1165011100']}
listBjdCodes.append(bjdCode)

bjdCode = {'name':'강남구','bjdcode':['1168010100',
'1168010300',
'1168010400',
'1168010500',
'1168010600',
'1168010700',
'1168010800',
'1168011000',
'1168011100',
'1168011200',
'1168011300',
'1168011400',
'1168011500',
'1168011800']}
listBjdCodes.append(bjdCode)

bjdCode = {'name':'송파구','bjdcode':['1171010100',
'1171010200',
'1171010300',
'1171010400',
'1171010500',
'1171010600',
'1171010700',
'1171010800',
'1171010900',
'1171011100',
'1171011200',
'1171011300',
'1171011400']}
listBjdCodes.append(bjdCode)

bjdCode = {'name':'강동구','bjdcode':['1174010100',
'1174010200',
'1174010300',
'1174010500',
'1174010600',
'1174010700',
'1174010800',
'1174010900',
'1174011000']}
listBjdCodes.append(bjdCode)

print(len(listBjdCodes))




for d in listBjdCodes:
    print(d['name'])
    
    rows = []
    
    for bjdCode in d['bjdcode']:
        
        req = requests.get("http://apis.data.go.kr/1611000/AptListService/getLegaldongAptList",
                           params = {"ServiceKey":api_key_decode, "pageNo":1,"numOfRows":100,"bjdCode":bjdCode} )

        #응답 파싱 
        import xml.etree.ElementTree as ET

        tree = ET.fromstring(req.text)
        # print(req.text)

        body = tree.find('body')
        items = body.find('items')

        print('count : ',len(items))

        # 아파트 기본정보
        urlAptNormal = "http://apis.data.go.kr/1611000/AptBasisInfoService/getAphusBassInfo"

        for item1 in items:
            data = {}
            # 아파트 기본정보 가져옴    
            kaptCode = item1.find('kaptCode').text   
        #     print(kaptCode)

            # 요청
            req2 = requests.get(urlAptNormal, params = {"ServiceKey":api_key_decode, "kaptCode":kaptCode})
            # 주소 가져옴
            item = ET.fromstring(req2.text).find('body').find('item')
            kaptAddr = item.find('kaptAddr').text

        #     print(kaptAddr)

            # Tmap Api를 통해서 주소 -> 좌표 변경 
            coord = requests.post('https://apis.openapi.sk.com/tmap/geo/fullAddrGeo?version=1&format=json&callback=result',
                                  data = {'appKey': 'l7xx212db90f6102453facd51f03ab73138f',
                                          'coordType': "WGS84GEO",
                                          "fullAddr": kaptAddr }).json()

            LAT_WGS = coord['coordinateInfo']['coordinate'][0]['lat']
            LON_WGS = coord['coordinateInfo']['coordinate'][0]['lon']

            data['LAT_WGS'] = LAT_WGS
            data['LON_WGS'] = LON_WGS

            data['kaptCode'] = kaptCode  
            try:
                data['kaptAcompany'] = item.find('kaptAcompany').text    
            except:
                pass
            try:
                data['bjdCode'] = item.find('bjdCode').text    
            except:
                pass
            try:
                data['codeAptNm'] = item.find('codeAptNm').text    
            except:
                pass

            try:
                data['codeHeatNm'] = item.find('codeHeatNm').text    
            except:
                pass
            try:
                data['codeMgrNm'] = item.find('codeMgrNm').text    
            except:
                pass
            try:
                data['codeSaleNm'] = item.find('codeSaleNm').text    
            except:
                pass

            try:
                data['doroJuso'] = item.find('doroJuso').text     
            except:
                pass   
            try:
                data['hoCnt'] = item.find('hoCnt').text    
            except:
                pass
            try:
                data['kaptBcompany'] = item.find('kaptBcompany').text    
            except:
                pass
            try:
                data['kaptCode'] = item.find('kaptCode').text    
            except:
                pass
            try:
                data['kaptDongCnt'] = item.find('kaptDongCnt').text    
            except:
                pass
            try:
                data['kaptFax'] = item.find('kaptFax').text    
            except:
                pass
            try:
                data['kaptMarea'] = item.find('kaptMarea').text    
            except:
                pass
            try:
                data['kaptMparea_135'] = item.find('kaptMparea_135').text    
            except:
                pass
            try:
                data['kaptMparea_136'] = item.find('kaptMparea_136').text      
            except:
                pass  
            try:
                data['kaptMparea_60'] = item.find('kaptMparea_60').text    
            except:
                pass
            try:
                data['kaptMparea_85'] = item.find('kaptMparea_85').text    
            except:
                pass
            try:
                data['kaptName'] = item.find('kaptName').text    
            except:
                pass
            try:
                data['kaptTarea'] = item.find('kaptTarea').text    
            except:
                pass
            try:
                data['kaptTel'] = item.find('kaptTel').text    
            except:
                pass
            try:
                data['kaptUsedate'] = item.find('kaptUsedate').text    
            except:
                pass
            try:
                data['kaptdaCnt'] = item.find('kaptdaCnt').text    
            except:
                pass
            try:
                data['privArea'] = item.find('privArea').text    
            except:
                pass

        #     print('LAT_WGS : ', LAT_WGS, ' LON_WGS : ', LON_WGS)

            rows.append(data)
            time.sleep(0.5)
        
        #json 파일로 저장
        import json
        fileName = 'apt_data_'+d['name']+'.json'

        with open(fileName, 'w', encoding='utf-8') as make_file:
            json.dump(rows, make_file, indent="\t")
# Out:
# 20
# 광진구
# count :  2
# count :  0
# count :  12
# count :  18
# count :  35
# count :  2
# count :  2
# 동대문구
# count :  1
# count :  7
# count :  6
# count :  10
# count :  24
# count :  13
# count :  6
# count :  2
# count :  15
# count :  13
# 중랑구
# count :  27
# count :  11
# count :  4
# count :  17
# count :  9
# count :  29
# 성북구
# count :  0
# count :  0
# count :  18
# count :  0
# count :  0
# count :  0
# count :  2
# count :  1
# count :  0
# count :  1
# count :  0
# count :  2
# count :  2
# count :  1
# count :  0
# count :  0
# count :  0
# count :  0
# count :  0
# count :  0
# count :  1
# count :  0
# count :  2
# count :  0
# count :  0
# count :  1
# count :  0
# count :  2
# count :  0
# count :  0
# count :  0
# count :  2
# count :  26
# count :  20
# count :  13
# count :  13
# count :  3
# count :  7
# count :  7
# 강북구
# count :  19
# count :  18
# count :  4
# count :  2
# 도봉구
# count :  22
# count :  27
# count :  37
# count :  18
# 은평구
# count :  5
# ...
